# %% [markdown]
# <a href="https://colab.research.google.com/github/Aakash-777/Linear-Regression/blob/main/Salary_pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv("Salary_dataset.csv")
x=ds.iloc[:,1].values
y=ds.iloc[:,-1].values
print(x)
print("\n")
print(y)
#print("\n")
#print(ds[1:])
#print(np.concatenate(x.reshape(len(x),1),y.reshape(len(y),1),1))
# Out:
# [ 1.2  1.4  1.6  2.1  2.3  3.   3.1  3.3  3.3  3.8  4.   4.1  4.1  4.2
#   4.6  5.   5.2  5.4  6.   6.1  6.9  7.2  8.   8.3  8.8  9.1  9.6  9.7
#  10.4 10.6]
#
#
# [ 39344.  46206.  37732.  43526.  39892.  56643.  60151.  54446.  64446.
#   57190.  63219.  55795.  56958.  57082.  61112.  67939.  66030.  83089.
#   81364.  93941.  91739.  98274. 101303. 113813. 109432. 105583. 116970.
#  112636. 122392. 121873.]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
x_train,x_test= x_train.reshape(-1,1),x_test.reshape(-1,1)
y_train,y_test= y_train.reshape(-1,1),y_test.reshape(-1,1)
print(x_train, x_test, y_train, y_test, sep="\n\n")
#print(np.concatenate((x_train,y_train),axis=1))
# Out:
# [[ 9.7]
#  [ 4.1]
#  [ 5.4]
#  [ 8. ]
#  [ 3. ]
#  [ 5.2]
#  [ 3.3]
#  [ 4.6]
#  [ 8.3]
#  [ 6.9]
#  [ 1.4]
#  [10.6]
#  [ 3.1]
#  [ 2.3]
#  [ 6. ]
#  [ 6.1]
#  [ 3.8]
#  [ 3.3]
#  [ 9.1]
#  [ 2.1]
#  [ 1.2]
#  [ 7.2]
#  [ 5. ]
#  [ 4.1]]
#
# [[ 1.6]
#  [10.4]
#  [ 4.2]
#  [ 4. ]
#  [ 9.6]
#  [ 8.8]]
#
# [[112636.]
#  [ 55795.]
#  [ 83089.]
#  [101303.]
#  [ 56643.]
#  [ 66030.]
#  [ 64446.]
#  [ 61112.]
#  [113813.]
#  [ 91739.]
#  [ 46206.]
#  [121873.]
#  [ 60151.]
#  [ 39892.]
#  [ 81364.]
#  [ 93941.]
#  [ 57190.]
#  [ 54446.]
#  [105583.]
#  [ 43526.]
#  [ 39344.]
#  [ 98274.]
#  [ 67939.]
#  [ 56958.]]
#
# [[ 37732.]
#  [122392.]
#  [ 57082.]
#  [ 63219.]
#  [116970.]
#  [109432.]]

# %%
from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)  #.reshape(-1,1)
print(y_pred)
#print(len(x_train),len(y_train))
#print(x_train.size,y_train.size)
#print(x_train)
# Out:
# [[ 40749.96184072]
#  [122700.62295594]
#  [ 64962.65717022]
#  [ 63100.14214487]
#  [115250.56285456]
#  [107800.50275317]]

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color="blue")
plt.title("Training Set")
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color="blue")
plt.title("Training Set")
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
